# %%
import requests
import pandas as pd

# MLB Stats API endpoint
base_url = "https://statsapi.mlb.com/api/v1/stats"

# Parameters for player hitting stats
params = {
    "stats": "season",       
    "group": "hitting",      
    "limit": 100,            
    "offset": 0,             
    "season": 2024,          
    "sportIds": 1            
}

all_players = []

while True:
    print(f"Fetching offset: {params['offset']}")
    res = requests.get(base_url, params=params)
    data = res.json()

    # Extract player records
    players = data.get("stats", [])[0].get("splits", [])
    if not players:
        break  # no more data

    for p in players:
        stat = p.get("stat", {})
        stat["player"] = p.get("player", {}).get("fullName", "")
        stat["team"] = p.get("team", {}).get("name", "")
        all_players.append(stat)

    # Move to next page
    params["offset"] += params["limit"]

# Convert to DataFrame
df = pd.DataFrame(all_players)

# Save to CSV
df.to_csv("mlb_hitting_stats.csv", index=False)
print("✅ Data saved to mlb_hitting_stats.csv")
# Out:
# Fetching offset: 0
# Fetching offset: 100
# Fetching offset: 200
# ✅ Data saved to mlb_hitting_stats.csv

# %%
df
# Out:
#      gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0            161         122      205   125       45       11        32
# 1            159         185      140    98       44        1        30
# 2            158          82      128   122       36        1        58
# 3            150         199      212    83       32        3         4
# 4            159         124      158   134       38        7        54
# ..           ...         ...      ...   ...      ...      ...       ...
# 124          157         163      148    50       24        0        17
# 125          131          80      130    59       14        0        26
# 126          136          74      152    73       21        7        18
# 127          138         102      110    60       20        2        17
# 128          152         131      145    56       11        3        21
#
#      strikeOuts  baseOnBalls  intentionalWalks  ...  rbi  leftOnBase sacBunts  \
# 0           106           57                 9  ...  109         181        0
# 1            96           72                12  ...  103         225        0
# 2           171          133                20  ...  144         238        0
# 3            29           24                 3  ...   46         181        2
# 4           162           81                10  ...  130         236        0
# ..          ...          ...               ...  ...  ...         ...      ...
# 124         128           41                 1  ...   46         254        1
# 125         149           53                 1  ...   82         233        0
# 126         137           48                 1  ...   58         201        1
# 127         188           38                 0  ...   49         231        3
# 128         159           61                 3  ...   60         240        0
#
#      sacFlies babip groundOutsToAirouts catchersInterference  \
# 0           8  .354                0.60                    0
# 1           4  .342                1.32                    0
# 2           2  .367                0.64                    1
# 3           1  .324                0.94                    0
# 4           5  .336                0.78                    3
# ..        ...   ...                 ...                  ...
# 124         7  .249                1.10                    0
# 125         6  .250                0.62                    2
# 126         1  .262                0.49                    0
# 127         5  .296                0.93                    0
# 128         5  .233                0.90                    0
#
#      atBatsPerHomeRun                 player                 team
# 0               19.88         Bobby Witt Jr.   Kansas City Royals
# 1               20.53  Vladimir Guerrero Jr.    Toronto Blue Jays
# 2                9.64            Aaron Judge     New York Yankees
# 3              159.25            Luis Arraez     San Diego Padres
# 4               11.78          Shohei Ohtani  Los Angeles Dodgers
# ..                ...                    ...                  ...
# 124             32.41          Orlando Arcia       Atlanta Braves
# 125             17.27           Rhys Hoskins    Milwaukee Brewers
# 126             25.50         Daulton Varsho    Toronto Blue Jays
# 127             29.24             Zack Gelof    Oakland Athletics
# 128             25.48      Christopher Morel       Tampa Bay Rays
#
# [129 rows x 34 columns]

# %%
# %pip install plotly

import numpy as np
import plotly.express as px
# Out:
# Requirement already satisfied: plotly in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (6.2.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from plotly) (1.47.0)
# Requirement already satisfied: packaging in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("mlb_hitting_stats.csv")
df.head()
# Out:
#    gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0          161         122      205   125       45       11        32
# 1          159         185      140    98       44        1        30
# 2          158          82      128   122       36        1        58
# 3          150         199      212    83       32        3         4
# 4          159         124      158   134       38        7        54
#
#    strikeOuts  baseOnBalls  intentionalWalks  ...  rbi  leftOnBase  sacBunts  \
# 0         106           57                 9  ...  109         181         0
# 1          96           72                12  ...  103         225         0
# 2         171          133                20  ...  144         238         0
# 3          29           24                 3  ...   46         181         2
# 4         162           81                10  ...  130         236         0
#
#    sacFlies  babip  groundOutsToAirouts  catchersInterference  \
# 0         8  0.354                 0.60                     0
# 1         4  0.342                 1.32                     0
# 2         2  0.367                 0.64                     1
# 3         1  0.324                 0.94                     0
# 4         5  0.336                 0.78                     3
#
#    atBatsPerHomeRun                 player                 team
# 0             19.88         Bobby Witt Jr.   Kansas City Royals
# 1             20.53  Vladimir Guerrero Jr.    Toronto Blue Jays
# 2              9.64            Aaron Judge     New York Yankees
# 3            159.25            Luis Arraez     San Diego Padres
# 4             11.78          Shohei Ohtani  Los Angeles Dodgers
#
# [5 rows x 34 columns]

# %%
## data exploration
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gamesPlayed           129 non-null    int64
#  1   groundOuts            129 non-null    int64
#  2   airOuts               129 non-null    int64
#  3   runs                  129 non-null    int64
#  4   doubles               129 non-null    int64
#  5   triples               129 non-null    int64
#  6   homeRuns              129 non-null    int64
#  7   strikeOuts            129 non-null    int64
#  8   baseOnBalls           129 non-null    int64
#  9   intentionalWalks      129 non-null    int64
#  10  hits                  129 non-null    int64
#  11  hitByPitch            129 non-null    int64
#  12  avg                   129 non-null    float64
#  13  atBats                129 non-null    int64
#  14  obp                   129 non-null    float64
#  15  slg                   129 non-null    float64
#  16  ops                   129 non-null    float64
#  17  caughtStealing        129 non-null    int64
#  18  stolenBases           129 non-null    int64
#  19  stolenBasePercentage  129 non-null    object
#  20  groundIntoDoublePlay  129 non-null    int64
#  21  numberOfPitches       129 non-null    int64
#  22  plateAppearances      129 non-null    int64
#  23  totalBases            129 non-null    int64
#  24  rbi                   129 non-null    int64
#  25  leftOnBase            129 non-null    int64
#  26  sacBunts              129 non-null    int64
#  27  sacFlies              129 non-null    int64
#  28  babip                 129 non-null    float64
#  29  groundOutsToAirouts   129 non-null    float64
#  30  catchersInterference  129 non-null    int64
#  31  atBatsPerHomeRun      129 non-null    float64
#  32  player                129 non-null    object
#  33  team                  129 non-null    object
# dtypes: float64(7), int64(24), object(3)
# memory usage: 34.4+ KB

# %%
df.describe()
# Out:
#        gamesPlayed  groundOuts     airOuts        runs     doubles  \
# count   129.000000  129.000000  129.000000  129.000000  129.000000
# mean    147.434109  131.705426  149.565891   77.379845   27.620155
# std      10.514755   27.934746   30.478693   17.209279    6.985693
# min     116.000000   72.000000   82.000000   46.000000   11.000000
# 25%     142.000000  114.000000  129.000000   65.000000   23.000000
# 50%     150.000000  128.000000  148.000000   74.000000   27.000000
# 75%     155.000000  150.000000  170.000000   85.000000   31.000000
# max     162.000000  199.000000  233.000000  134.000000   48.000000
#
#           triples    homeRuns  strikeOuts  baseOnBalls  intentionalWalks  ...  \
# count  129.000000  129.000000  129.000000   129.000000        129.000000  ...
# mean     2.449612   21.674419  128.480620    53.503876          2.635659  ...
# std      2.588922    9.134552   33.990371    18.710844          3.450403  ...
# min      0.000000    2.000000   29.000000    15.000000          0.000000  ...
# 25%      1.000000   16.000000  103.000000    41.000000          1.000000  ...
# 50%      2.000000   20.000000  127.000000    52.000000          2.000000  ...
# 75%      3.000000   26.000000  156.000000    65.000000          3.000000  ...
# max     14.000000   58.000000  218.000000   133.000000         20.000000  ...
#
#        plateAppearances  totalBases         rbi  leftOnBase    sacBunts  \
# count        129.000000  129.000000  129.000000  129.000000  129.000000
# mean         611.403101  238.860465   75.178295  220.333333    0.798450
# std           60.108693   46.868290   18.977556   32.873653    1.470437
# min          507.000000  155.000000   32.000000  131.000000    0.000000
# 25%          561.000000  206.000000   62.000000  199.000000    0.000000
# 50%          619.000000  231.000000   74.000000  221.000000    0.000000
# 75%          654.000000  261.000000   86.000000  237.000000    1.000000
# max          735.000000  411.000000  144.000000  291.000000    9.000000
#
#          sacFlies       babip  groundOutsToAirouts  catchersInterference  \
# count  129.000000  129.000000           129.000000            129.000000
# mean     4.302326    0.299147             0.917132              0.310078
# std      2.412871    0.029717             0.271869              0.836646
# min      0.000000    0.225000             0.440000              0.000000
# 25%      2.000000    0.279000             0.730000              0.000000
# 50%      4.000000    0.300000             0.890000              0.000000
# 75%      6.000000    0.318000             1.100000              0.000000
# max     13.000000    0.370000             1.900000              5.000000
#
#        atBatsPerHomeRun
# count        129.000000
# mean          32.066202
# std           27.094796
# min            9.640000
# 25%           21.590000
# 50%           26.050000
# 75%           33.940000
# max          237.500000
#
# [8 rows x 31 columns]

# %%
df.describe(include='object')
# Out:
#        stolenBasePercentage          player          team
# count                   129             129           129
# unique                   57             129            30
# top                   1.000  Bobby Witt Jr.  Chicago Cubs
# freq                     20               1             7

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 124    False
# 125    False
# 126    False
# 127    False
# 128    False
# Length: 129, dtype: bool

# %%
df.isna().sum()
# Out:
# gamesPlayed             0
# groundOuts              0
# airOuts                 0
# runs                    0
# doubles                 0
# triples                 0
# homeRuns                0
# strikeOuts              0
# baseOnBalls             0
# intentionalWalks        0
# hits                    0
# hitByPitch              0
# avg                     0
# atBats                  0
# obp                     0
# slg                     0
# ops                     0
# caughtStealing          0
# stolenBases             0
# stolenBasePercentage    0
# groundIntoDoublePlay    0
# numberOfPitches         0
# plateAppearances        0
# totalBases              0
# rbi                     0
# leftOnBase              0
# sacBunts                0
# sacFlies                0
# babip                   0
# groundOutsToAirouts     0
# catchersInterference    0
# atBatsPerHomeRun        0
# player                  0
# team                    0
# dtype: int64

# %%
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
categorical_cols
# Out:
# ['stolenBasePercentage', 'player', 'team']

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_cols
# Out:
# ['gamesPlayed',
#  'groundOuts',
#  'airOuts',
#  'runs',
#  'doubles',
#  'triples',
#  'homeRuns',
#  'strikeOuts',
#  'baseOnBalls',
#  'intentionalWalks',
#  'hits',
#  'hitByPitch',
#  'avg',
#  'atBats',
#  'obp',
#  'slg',
#  'ops',
#  'caughtStealing',
#  'stolenBases',
#  'groundIntoDoublePlay',
#  'numberOfPitches',
#  'plateAppearances',
#  'totalBases',
#  'rbi',
#  'leftOnBase',
#  'sacBunts',
#  'sacFlies',
#  'babip',
#  'groundOutsToAirouts',
#  'catchersInterference',
#  'atBatsPerHomeRun']

# %%
for col in categorical_cols:
    print(col)
    print(df[col].nunique())
    print(df[col].unique())
    print('-' * 100)
# Out:
# stolenBasePercentage
# 57
# ['.721' '.500' '1.000' '.750' '.937' '.826' '.759' '.786' '.842' '.706'
#  '.875' '.889' '.636' '.829' '.727' '.818' '.815' '.840' '.---' '.769'
#  '.714' '.854' '.833' '.846' '.879' '.828' '.838' '.800' '.857' '.692'
#  '.545' '.688' '.667' '.807' '.957' '.000' '.571' '.767' '.893' '.778'
#  '.864' '.909' '.625' '.867' '.609' '.882' '.655' '.600' '.914' '.400'
#  '.647' '.696' '.949' '.814' '.793' '.941' '.533']
# ----------------------------------------------------------------------------------------------------
# player
# 129
# ['Bobby Witt Jr.' 'Vladimir Guerrero Jr.' 'Aaron Judge' 'Luis Arraez'
#  'Shohei Ohtani' 'Yordan Alvarez' 'Marcell Ozuna' 'Yainer Diaz'
#  'Trea Turner' 'Jose Altuve' 'Brent Rooker' 'Jackson Merrill'
#  'Steven Kwan' 'Ketel Marte' 'Mookie Betts' 'Juan Soto' 'Bryce Harper'
#  'Jarren Duran' 'Seiya Suzuki' 'Freddie Freeman' 'Luis García Jr.'
#  'Gunnar Henderson' 'William Contreras' 'Yandy Díaz' 'Jurickson Profar'
#  'Alec Bohm' 'José Ramírez' 'Lourdes Gurriel Jr.' 'Corey Seager'
#  'Brendan Donovan' 'Bryan Reynolds' 'Manny Machado' 'Jackson Chourio'
#  'Francisco Lindor' 'Julio Rodríguez' 'Nico Hoerner' 'Rafael Devers'
#  'Teoscar Hernández' 'Nolan Arenado' 'Salvador Perez' 'Ryan Mountcastle'
#  'Heliot Ramos' 'Alec Burleson' 'Ezequiel Tovar' 'Brendan Rodgers'
#  'Masyn Winn' 'Jeremy Peña' 'Cody Bellinger' 'Nathaniel Lowe'
#  'Vinnie Pasquantino' 'Riley Greene' 'Brenton Doyle' 'Alex Bregman'
#  'Colt Keith' 'Sal Frelick' 'Elly De La Cruz' 'Oneil Cruz' 'Justin Turner'
#  'Tyler Stephenson' 'Josh Smith' 'Gleyber Torres' 'Matt Vierling'
#  'Jacob Young' 'Jazz Chisholm Jr.' 'Eugenio Suárez' 'Nick Castellanos'
#  'Brice Turang' 'Jesse Winker' 'Wyatt Langford' 'Andrés Giménez'
#  'Jesús Sánchez' 'Willy Adames' 'Christian Walker' 'Nolan Schanuel'
#  'Jake Burger' 'Adley Rutschman' 'Zach Neto' 'Josh Bell' 'Michael Busch'
#  'Will Smith' 'Kyle Schwarber' 'Jonathan India' 'Willi Castro'
#  'Matt Chapman' 'Matt Olson' 'Ceddanne Rafaela' 'Taylor Ward' 'CJ Abrams'
#  'Andrew Vaughn' 'Paul Goldschmidt' 'Bryson Stott' "Logan O'Hoppe"
#  'Josh Naylor' 'Anthony Volpe' 'JJ Bleday' 'Ian Happ' 'Colton Cowser'
#  'Ryan McMahon' 'Dansby Swanson' 'Jorge Soler' 'Jake Cronenworth'
#  'Pete Alonso' 'Joey Ortiz' 'Isaac Paredes' 'Carlos Santana' 'Lane Thomas'
#  'Marcus Semien' 'Anthony Santander' 'Ty France' 'Bryan De La Cruz'
#  'Alex Verdugo' 'Andrew McCutchen' 'Maikel Garcia' 'Corbin Carroll'
#  'Leody Taveras' 'Andrew Benintendi' 'Spencer Steer' 'Brandon Nimmo'
#  'Adolis García' 'Shea Langeliers' 'George Springer' 'Cal Raleigh'
#  'Jake Meyers' 'Randy Arozarena' 'Orlando Arcia' 'Rhys Hoskins'
#  'Daulton Varsho' 'Zack Gelof' 'Christopher Morel']
# ----------------------------------------------------------------------------------------------------
# team
# 30
# ['Kansas City Royals' 'Toronto Blue Jays' 'New York Yankees'
#  'San Diego Padres' 'Los Angeles Dodgers' 'Houston Astros'
#  'Atlanta Braves' 'Philadelphia Phillies' 'Oakland Athletics'
#  'Cleveland Guardians' 'Arizona Diamondbacks' 'Boston Red Sox'
#  'Chicago Cubs' 'Washington Nationals' 'Baltimore Orioles'
#  'Milwaukee Brewers' 'Tampa Bay Rays' 'Texas Rangers'
#  'St. Louis Cardinals' 'Pittsburgh Pirates' 'New York Mets'
#  'Seattle Mariners' 'San Francisco Giants' 'Colorado Rockies'
#  'Detroit Tigers' 'Cincinnati Reds' 'Miami Marlins' 'Los Angeles Angels'
#  'Minnesota Twins' 'Chicago White Sox']
# ----------------------------------------------------------------------------------------------------

# %%
# Convert 'stolenBasePercentage' to numeric
df['stolenBasePercentage'] = pd.to_numeric(
    df['stolenBasePercentage'].apply(lambda x: '0' + x if isinstance(x, str) and x.startswith('.') else x),
    errors='coerce'
)

# Add to numerical_cols 
if 'stolenBasePercentage' not in numerical_cols:
    numerical_cols.append('stolenBasePercentage')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gamesPlayed           129 non-null    int64
#  1   groundOuts            129 non-null    int64
#  2   airOuts               129 non-null    int64
#  3   runs                  129 non-null    int64
#  4   doubles               129 non-null    int64
#  5   triples               129 non-null    int64
#  6   homeRuns              129 non-null    int64
#  7   strikeOuts            129 non-null    int64
#  8   baseOnBalls           129 non-null    int64
#  9   intentionalWalks      129 non-null    int64
#  10  hits                  129 non-null    int64
#  11  hitByPitch            129 non-null    int64
#  12  avg                   129 non-null    float64
#  13  atBats                129 non-null    int64
#  14  obp                   129 non-null    float64
#  15  slg                   129 non-null    float64
#  16  ops                   129 non-null    float64
#  17  caughtStealing        129 non-null    int64
#  18  stolenBases           129 non-null    int64
#  19  stolenBasePercentage  126 non-null    float64
#  20  groundIntoDoublePlay  129 non-null    int64
#  21  numberOfPitches       129 non-null    int64
#  22  plateAppearances      129 non-null    int64
#  23  totalBases            129 non-null    int64
#  24  rbi                   129 non-null    int64
#  25  leftOnBase            129 non-null    int64
#  26  sacBunts              129 non-null    int64
#  27  sacFlies              129 non-null    int64
#  28  babip                 129 non-null    float64
#  29  groundOutsToAirouts   129 non-null    float64
#  30  catchersInterference  129 non-null    int64
#  31  atBatsPerHomeRun      129 non-null    float64
#  32  player                129 non-null    object
#  33  team                  129 non-null    object
# dtypes: float64(8), int64(24), object(2)
# memory usage: 34.4+ KB

# %%
df['stolenBasePercentage'].isna().mean()*100
# Out:
# np.float64(2.3255813953488373)

# %%
import plotly.express as px

for col in numerical_cols:
    fig = px.histogram(df, x=col, nbins=20, title=f"Distribution of {col}")
    fig.show()

# %%
import plotly.graph_objects as go

for col in numerical_cols:
    fig = go.Figure()
    fig.add_trace(go.Box(y=df[col], name=col, boxpoints='outliers'))
    fig.update_layout(title=f"Boxplot of {col}", yaxis_title=col)
    fig.show()

# %%
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
categorical_cols
# Out:
# ['player', 'team']

# %%
import plotly.express as px

for col in categorical_cols:
    value_counts = df[col].value_counts().reset_index()
    value_counts.columns = [col, 'count']
    fig = px.bar(
        value_counts,
        x=col,
        y='count',
        title=f"Bar Chart of {col}",
        labels={col: col, 'count': 'Count'}
    )
    fig.show()

# %%
import plotly.express as px

# Compute the correlation matrix for numerical columns
corr_matrix = df[numerical_cols].corr()

fig = px.imshow(
    corr_matrix,
    labels=dict(x="Features", y="Features", color="Correlation"),
    x=corr_matrix.columns,
    y=corr_matrix.columns,
    color_continuous_scale="RdBu",
    zmin=-1, zmax=1,
    title="Correlation Matrix Heatmap"
)
fig.update_layout(width=900, height=900)
fig.show()

# %%
# Remove outliers from numerical 
Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
IQR = Q3 - Q1

# Keep only rows without outliers 
df_clean = df[~((df[numerical_cols] < (Q1 - 1.5 * IQR)) | (df[numerical_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 7 to 128
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gamesPlayed           58 non-null     int64
#  1   groundOuts            58 non-null     int64
#  2   airOuts               58 non-null     int64
#  3   runs                  58 non-null     int64
#  4   doubles               58 non-null     int64
#  5   triples               58 non-null     int64
#  6   homeRuns              58 non-null     int64
#  7   strikeOuts            58 non-null     int64
#  8   baseOnBalls           58 non-null     int64
#  9   intentionalWalks      58 non-null     int64
#  10  hits                  58 non-null     int64
#  11  hitByPitch            58 non-null     int64
#  12  avg                   58 non-null     float64
#  13  atBats                58 non-null     int64
#  14  obp                   58 non-null     float64
#  15  slg                   58 non-null     float64
#  16  ops                   58 non-null     float64
#  17  caughtStealing        58 non-null     int64
#  18  stolenBases           58 non-null     int64
#  19  stolenBasePercentage  57 non-null     float64
#  20  groundIntoDoublePlay  58 non-null     int64
#  21  numberOfPitches       58 non-null     int64
#  22  plateAppearances      58 non-null     int64
#  23  totalBases            58 non-null     int64
#  24  rbi                   58 non-null     int64
#  25  leftOnBase            58 non-null     int64
#  26  sacBunts              58 non-null     int64
#  27  sacFlies              58 non-null     int64
#  28  babip                 58 non-null     float64
#  29  groundOutsToAirouts   58 non-null     float64
#  30  catchersInterference  58 non-null     int64
#  31  atBatsPerHomeRun      58 non-null     float64
#  32  player                58 non-null     object
#  33  team                  58 non-null     object
# dtypes: float64(8), int64(24), object(2)
# memory usage: 15.9+ KB

# %%
# Fill missing values in 'stolenBasePercentage' with the column mean
df_clean['stolenBasePercentage'] = df_clean['stolenBasePercentage'].fillna(df_clean['stolenBasePercentage'].mean())
# Out:
# C:\Users\ayman\AppData\Local\Temp\ipykernel_32352\3444103350.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 7 to 128
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gamesPlayed           58 non-null     int64
#  1   groundOuts            58 non-null     int64
#  2   airOuts               58 non-null     int64
#  3   runs                  58 non-null     int64
#  4   doubles               58 non-null     int64
#  5   triples               58 non-null     int64
#  6   homeRuns              58 non-null     int64
#  7   strikeOuts            58 non-null     int64
#  8   baseOnBalls           58 non-null     int64
#  9   intentionalWalks      58 non-null     int64
#  10  hits                  58 non-null     int64
#  11  hitByPitch            58 non-null     int64
#  12  avg                   58 non-null     float64
#  13  atBats                58 non-null     int64
#  14  obp                   58 non-null     float64
#  15  slg                   58 non-null     float64
#  16  ops                   58 non-null     float64
#  17  caughtStealing        58 non-null     int64
#  18  stolenBases           58 non-null     int64
#  19  stolenBasePercentage  58 non-null     float64
#  20  groundIntoDoublePlay  58 non-null     int64
#  21  numberOfPitches       58 non-null     int64
#  22  plateAppearances      58 non-null     int64
#  23  totalBases            58 non-null     int64
#  24  rbi                   58 non-null     int64
#  25  leftOnBase            58 non-null     int64
#  26  sacBunts              58 non-null     int64
#  27  sacFlies              58 non-null     int64
#  28  babip                 58 non-null     float64
#  29  groundOutsToAirouts   58 non-null     float64
#  30  catchersInterference  58 non-null     int64
#  31  atBatsPerHomeRun      58 non-null     float64
#  32  player                58 non-null     object
#  33  team                  58 non-null     object
# dtypes: float64(8), int64(24), object(2)
# memory usage: 15.9+ KB

# %%
df = df_clean.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 7 to 128
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gamesPlayed           58 non-null     int64
#  1   groundOuts            58 non-null     int64
#  2   airOuts               58 non-null     int64
#  3   runs                  58 non-null     int64
#  4   doubles               58 non-null     int64
#  5   triples               58 non-null     int64
#  6   homeRuns              58 non-null     int64
#  7   strikeOuts            58 non-null     int64
#  8   baseOnBalls           58 non-null     int64
#  9   intentionalWalks      58 non-null     int64
#  10  hits                  58 non-null     int64
#  11  hitByPitch            58 non-null     int64
#  12  avg                   58 non-null     float64
#  13  atBats                58 non-null     int64
#  14  obp                   58 non-null     float64
#  15  slg                   58 non-null     float64
#  16  ops                   58 non-null     float64
#  17  caughtStealing        58 non-null     int64
#  18  stolenBases           58 non-null     int64
#  19  stolenBasePercentage  58 non-null     float64
#  20  groundIntoDoublePlay  58 non-null     int64
#  21  numberOfPitches       58 non-null     int64
#  22  plateAppearances      58 non-null     int64
#  23  totalBases            58 non-null     int64
#  24  rbi                   58 non-null     int64
#  25  leftOnBase            58 non-null     int64
#  26  sacBunts              58 non-null     int64
#  27  sacFlies              58 non-null     int64
#  28  babip                 58 non-null     float64
#  29  groundOutsToAirouts   58 non-null     float64
#  30  catchersInterference  58 non-null     int64
#  31  atBatsPerHomeRun      58 non-null     float64
#  32  player                58 non-null     object
#  33  team                  58 non-null     object
# dtypes: float64(8), int64(24), object(2)
# memory usage: 15.9+ KB

# %%
# %pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (1.16.0)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from scipy) (2.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from scikit-learn) (2.2.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#      gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 7            148         191      120    70       29        3        16
# 9            153         153      171    94       31        0        20
# 18           132          72      139    74       27        6        21
# 20           140         150      124    58       25        1        18
# 22           155         175      117    99       37        2        23
# 27           133         117      157    72       22        2        18
# 29           153         163      185    65       34        3        14
# 30           156         158      140    73       29        3        24
# 32           148         141      124    80       29        4        21
# 33           152         130      195   107       39        1        33
# 34           143         129      129    76       17        0        20
# 40           124         120      117    54       30        2        13
# 48           140         128      108    62       16        1        16
# 52           145         136      212    79       30        2        26
# 53           148         130      144    54       15        4        13
# 56           146         125       99    72       34        3        21
# 58           138         124      100    69       26        1        19
# 59           149         116      156    67       30        1        13
# 60           154         131      179    80       26        0        15
# 61           144         123      146    80       28        5        16
# 63           147         143      125    74       21        4        24
# 64           158         101      159    90       28        2        30
# 65           162         141      174    80       30        4        23
# 67           145         114      106    63       23        0        14
# 68           134         110      151    74       25        4        16
# 70           149         133       95    60       25        1        18
# 71           161         102      185    93       33        0        32
# 72           130          94      140    72       26        0        26
# 74           137         123      132    68       23        1        29
# 75           148         128      204    68       21        1        19
# 78           152         102      113    73       28        2        21
# 79           128          94      167    77       24        2        20
# 81           151         141      144    84       28        2        15
# 83           154         118      159    98       39        2        27
# 84           162         126      161    78       37        1        29
# 85           152         129      135    70       23        5        15
# 86           156         100      186    73       26        2        25
# 88           149         124      179    55       30        1        19
# 90           148         132      166    65       19        2        11
# 91           136          94      115    64       17        1        20
# 94           159         119      190    74       43        4        20
# 95           153         114      151    89       34        2        25
# 96           153         109      100    77       24        3        24
# 98           149         151      113    82       27        2        16
# 101          162         140      154    91       31        0        34
# 103          153         114      200    64       25        1        19
# 104          150         124      176    63       26        0        23
# 106          159         161      231   101       27        2        23
# 108          140         129      129    46       24        0        13
# 110          149         190      158    74       28        1        13
# 115          135         122      153    50       20        0        20
# 116          158         129      181    74       34        4        20
# 117          151         138      150    88       25        3        23
# 118          154         119      160    68       27        0        25
# 119          137         106      129    58       18        2        29
# 121          153          84      172    73       16        0        34
# 124          157         163      148    50       24        0        17
# 128          152         131      145    56       11        3        21
#
#      strikeOuts  baseOnBalls  intentionalWalks  ...  rbi  leftOnBase  \
# 7           107           24                 1  ...   84         268
# 9           119           47                 2  ...   65         193
# 18          160           63                 3  ...   73         220
# 20           86           27                 2  ...   70         197
# 22          139           78                 5  ...   92         224
# 27          101           29                 1  ...   75         220
# 29           81           47                 0  ...   73         228
# 30          156           57                 3  ...   88         231
# 32          121           39                 4  ...   79         200
# 33          127           56                 0  ...   91         223
# 34          156           38                 1  ...   68         228
# 40          114           27                 0  ...   63         199
# 48          125           71                 1  ...   69         198
# 52           86           44                 1  ...   75         269
# 53          110           36                 2  ...   61         193
# 56          181           51                 5  ...   76         268
# 58          117           48                 2  ...   66         172
# 59          121           46                 1  ...   62         189
# 60          136           65                 0  ...   63         222
# 61          121           41                 1  ...   57         200
# 63          152           53                 5  ...   73         242
# 64          176           49                 0  ...  101         266
# 65          139           41                 2  ...   86         262
# 67          106           63                 2  ...   58         169
# 68          115           51                 3  ...   74         220
# 70          140           41                 2  ...   64         226
# 71          173           74                 3  ...  112         285
# 72          133           55                 4  ...   84         230
# 74          150           31                 2  ...   76         209
# 75          103           58                 3  ...   79         213
# 78          162           63                 1  ...   65         218
# 79          105           51                 6  ...   75         206
# 81          125           80                 0  ...   58         153
# 83          158           64                 3  ...   78         248
# 84          170           71                 5  ...   98         275
# 85          151           15                 1  ...   75         250
# 86          163           63                 0  ...   75         208
# 88          132           38                 0  ...   70         233
# 90           93           53                 1  ...   57         209
# 91          155           33                 0  ...   56         177
# 94          125           67                 2  ...   60         227
# 95          168           80                 1  ...   86         213
# 96          172           52                 2  ...   69         236
# 98          144           54                 2  ...   66         218
# 101         172           70                 4  ...   88         291
# 103         105           76                 2  ...   80         226
# 104          99           65                 3  ...   71         244
# 106         105           64                 2  ...   74         208
# 108         114           38                 0  ...   51         202
# 110          93           49                 0  ...   61         271
# 115          96           41                 1  ...   64         194
# 116         137           72                 1  ...   92         227
# 117         158           77                 1  ...   90         217
# 118         177           45                 2  ...   85         284
# 119         145           41                 2  ...   80         253
# 121         176           70                 4  ...  100         263
# 124         128           41                 1  ...   46         254
# 128         159           61                 3  ...   60         240
#
#      sacBunts  sacFlies  babip  groundOutsToAirouts  catchersInterference  \
# 7           0         8  0.338                 1.59                     0
# 9           0         0  0.337                 0.89                     0
# 18          0         4  0.370                 0.52                     0
# 20          0         1  0.310                 1.21                     0
# 22          0         3  0.330                 1.50                     0
# 27          0         5  0.313                 0.75                     0
# 29          0         5  0.300                 0.88                     0
# 30          0         3  0.330                 1.13                     0
# 32          1         2  0.320                 1.14                     0
# 33          0         3  0.295                 0.67                     0
# 34          0         2  0.344                 1.00                     0
# 40          0         6  0.327                 1.03                     0
# 48          0         4  0.324                 1.19                     0
# 52          0         4  0.264                 0.64                     0
# 53          0         2  0.306                 0.90                     0
# 56          0         4  0.347                 1.26                     0
# 58          0         2  0.307                 1.24                     0
# 59          2         3  0.311                 0.74                     0
# 60          2         8  0.306                 0.73                     0
# 61          0         5  0.303                 0.84                     0
# 63          0         2  0.309                 1.14                     0
# 64          0        11  0.309                 0.64                     0
# 65          0         2  0.294                 0.81                     0
# 67          2         3  0.304                 1.08                     0
# 68          0         3  0.296                 0.73                     0
# 70          1         2  0.315                 1.40                     0
# 71          0         3  0.297                 0.55                     0
# 72          0         8  0.287                 0.67                     0
# 74          0         4  0.292                 0.93                     0
# 75          0         7  0.272                 0.63                     0
# 78          0         4  0.322                 0.90                     0
# 79          0         8  0.273                 0.56                     0
# 81          2         7  0.293                 0.98                     0
# 83          0         2  0.293                 0.74                     0
# 84          0         5  0.293                 0.78                     0
# 85          2         3  0.312                 0.96                     0
# 86          0         8  0.294                 0.54                     0
# 88          0         5  0.285                 0.69                     0
# 90          0         9  0.275                 0.80                     0
# 91          1         1  0.318                 0.82                     0
# 94          1         0  0.279                 0.63                     0
# 95          0         2  0.299                 0.75                     0
# 96          0         3  0.317                 1.09                     0
# 98          0         3  0.300                 1.34                     0
# 101         0         4  0.276                 0.91                     0
# 103         0         6  0.259                 0.57                     0
# 104         0         2  0.252                 0.70                     0
# 106         0         1  0.250                 0.70                     0
# 108         0         5  0.277                 1.00                     0
# 110         2        10  0.253                 1.20                     0
# 115         0         3  0.245                 0.80                     0
# 116         0         2  0.260                 0.71                     0
# 117         0         3  0.267                 0.92                     0
# 118         0         6  0.273                 0.74                     0
# 119         0         6  0.252                 0.82                     0
# 121         0         6  0.251                 0.49                     0
# 124         1         7  0.249                 1.10                     0
# 128         0         5  0.233                 0.90                     0
#
#      atBatsPerHomeRun               player                   team
# 7               36.56          Yainer Diaz         Houston Astros
# 9               31.40          Jose Altuve         Houston Astros
# 18              24.38         Seiya Suzuki           Chicago Cubs
# 20              27.78      Luis García Jr.   Washington Nationals
# 22              25.87    William Contreras      Milwaukee Brewers
# 27              28.50  Lourdes Gurriel Jr.   Arizona Diamondbacks
# 29              41.93      Brendan Donovan    St. Louis Cardinals
# 30              25.92       Bryan Reynolds     Pittsburgh Pirates
# 32              25.14      Jackson Chourio      Milwaukee Brewers
# 33              18.73     Francisco Lindor          New York Mets
# 34              28.35      Julio Rodríguez       Seattle Mariners
# 40              36.38     Ryan Mountcastle      Baltimore Orioles
# 48              30.38       Nathaniel Lowe          Texas Rangers
# 52              22.35         Alex Bregman         Houston Astros
# 53              39.69           Colt Keith         Detroit Tigers
# 56              25.76           Oneil Cruz     Pittsburgh Pirates
# 58              24.05     Tyler Stephenson        Cincinnati Reds
# 59              40.23           Josh Smith          Texas Rangers
# 60              39.13       Gleyber Torres       New York Yankees
# 61              32.38        Matt Vierling         Detroit Tigers
# 63              23.42    Jazz Chisholm Jr.       New York Yankees
# 64              19.03       Eugenio Suárez   Arizona Diamondbacks
# 65              26.35     Nick Castellanos  Philadelphia Phillies
# 67              30.71         Jesse Winker          New York Mets
# 68              31.19       Wyatt Langford          Texas Rangers
# 70              27.17        Jesús Sánchez          Miami Marlins
# 71              19.06         Willy Adames      Milwaukee Brewers
# 72              18.42     Christian Walker   Arizona Diamondbacks
# 74              18.45          Jake Burger          Miami Marlins
# 75              30.05      Adley Rutschman      Baltimore Orioles
# 78              23.62        Michael Busch           Chicago Cubs
# 79              23.80           Will Smith    Los Angeles Dodgers
# 81              35.53       Jonathan India        Cincinnati Reds
# 83              21.30         Matt Chapman   San Francisco Giants
# 84              20.69           Matt Olson         Atlanta Braves
# 85              36.27     Ceddanne Rafaela         Boston Red Sox
# 86              23.40          Taylor Ward     Los Angeles Angels
# 88              30.00        Andrew Vaughn      Chicago White Sox
# 90              46.00         Bryson Stott  Philadelphia Phillies
# 91              23.95        Logan O'Hoppe     Los Angeles Angels
# 94              28.60            JJ Bleday      Oakland Athletics
# 95              22.76             Ian Happ           Chicago Cubs
# 96              20.79        Colton Cowser      Baltimore Orioles
# 98              33.38       Dansby Swanson           Chicago Cubs
# 101             17.88          Pete Alonso          New York Mets
# 103             28.53        Isaac Paredes           Chicago Cubs
# 104             22.65       Carlos Santana        Minnesota Twins
# 106             28.26        Marcus Semien          Texas Rangers
# 108             36.85            Ty France        Cincinnati Reds
# 110             43.00         Alex Verdugo       New York Yankees
# 115             23.85    Andrew Benintendi      Chicago White Sox
# 116             28.70        Spencer Steer        Cincinnati Reds
# 117             24.83        Brandon Nimmo          New York Mets
# 118             23.20        Adolis García          Texas Rangers
# 119             16.62      Shea Langeliers      Oakland Athletics
# 121             16.06          Cal Raleigh       Seattle Mariners
# 124             32.41        Orlando Arcia         Atlanta Braves
# 128             25.48    Christopher Morel         Tampa Bay Rays
#
# [58 rows x 34 columns]

# %%
from scipy.stats import skew
import numpy as np
from sklearn.preprocessing import PowerTransformer

# numerical_cols is already defined in previous cells
# If not, re-define it here:
# numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Use the existing numerical_cols variable from previous cells
skewed_cols = [col for col in numerical_cols if abs(skew(df[col].dropna())) > 0.75]

# Apply log1p transformation to handle positive skewness
for col in skewed_cols:
    # Only apply if all values are >= 0
    if (df[col] >= 0).all():
        df[col] = np.log1p(df[col])
    else:
        # For columns with negative values, use a different transformation (e.g., Yeo-Johnson)
        pt = PowerTransformer(method='yeo-johnson')
        df[col] = pt.fit_transform(df[[col]])

# Check skewness after transformation
{col: skew(df[col].dropna()) for col in skewed_cols}
# Out:
# {'caughtStealing': np.float64(-0.05257666509746663),
#  'stolenBases': np.float64(-0.062322313313329075),
#  'sacBunts': np.float64(1.7865692875075025)}

# %%
import plotly.express as px

for col in numerical_cols:
    fig = px.histogram(df_clean, x=col, nbins=20, title=f"Distribution of {col} (Cleaned Data)")
    fig.show()

# %%
df.to_csv("mlb_hitting_stats_cleaned.csv", index=False)
print("✅ Cleaned data saved to mlb_hitting_stats_cleaned.csv")
# Out:
# ✅ Cleaned data saved to mlb_hitting_stats_cleaned.csv

# %%
# what is the average stolen base percentage by team?
team_sb_eff = df.groupby("team")["stolenBasePercentage"].mean().sort_values(ascending=False).reset_index()

fig = px.bar(team_sb_eff, x="team", y="stolenBasePercentage",
             title="Average Stolen Base Percentage by Team",
             labels={"stolenBasePercentage": "Stolen Base %"})
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()

# %%
# is there a relationship between games played and stolen bases?
fig = px.scatter(df, x="gamesPlayed", y="stolenBases",
                 hover_name="player", color="team",
                 title="Stolen Bases vs Games Played")
fig.show()

# %%
#What is the home run rate (homeRuns / atBats) for each player?
df["homeRunRate"] = df["homeRuns"] / df["atBats"]

top_power_hitters = df[df["atBats"] > 100].sort_values("homeRunRate", ascending=False).head(10)

fig = px.bar(top_power_hitters, x="player", y="homeRunRate", color="team",
             title="Top 10 Power Hitters (HR Rate, Min 100 AB)")
fig.show()

# %%
# Is there a relationship between batting average and on-base percentage?
fig = px.scatter(df, x="avg", y="obp", 
                 color="team", hover_name="player",
                 title="Batting Average vs On-Base Percentage")
fig.show()

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (1.46.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: packaging<26,>=20 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (6.31.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from altair<6,>=4.0->streamlit) (1.47.0)
# Requirement already satisfied: colorama in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\ayman\anaconda3\envs\descriptivestat\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile mlb_analysis_app.py
import streamlit as st
import pandas as pd
import plotly.express as px

# Load data
df = pd.read_csv("mlb_hitting_stats_cleaned.csv")

# Calculate derived columns if needed
df["homeRunRate"] = df["homeRuns"] / df["atBats"]

# Sidebar navigation
st.sidebar.title("MLB Hitting Stats Explorer")
menu = st.sidebar.radio("Select Analysis Type:", ["Univariate Analysis", "Bivariate Analysis"])

st.title("⚾ MLB Hitting Stats Dashboard")

if menu == "Univariate Analysis":
    st.header("Univariate Analysis")
    plot_type = st.sidebar.selectbox("Choose Plot Type:", ["Histogram", "Boxplot", "Bar Chart"])

    if plot_type == "Histogram":
        numeric_col = st.selectbox("Select numerical column:", df.select_dtypes(include='number').columns)
        fig = px.histogram(df, x=numeric_col, nbins=30, title=f"Distribution of {numeric_col}")
        st.plotly_chart(fig)

    elif plot_type == "Boxplot":
        numeric_col = st.selectbox("Select numerical column:", df.select_dtypes(include='number').columns)
        fig = px.box(df, y=numeric_col, title=f"Boxplot of {numeric_col}")
        st.plotly_chart(fig)

    elif plot_type == "Bar Chart":
        cat_col = st.selectbox("Select categorical column:", df.select_dtypes(include='object').columns)
        bar_data = df[cat_col].value_counts().reset_index()
        bar_data.columns = [cat_col, "count"]
        fig = px.bar(bar_data, x=cat_col, y="count", title=f"Bar Chart of {cat_col}")
        st.plotly_chart(fig)

elif menu == "Bivariate Analysis":
    st.header("Bivariate Analysis")
    analysis_option = st.sidebar.selectbox("Select Analysis Question:", [
        "Average Stolen Base Percentage by Team",
        "Stolen Bases vs Games Played",
        "Top 10 Power Hitters",
        "Batting Average vs On-Base Percentage"
    ])

    if analysis_option == "Average Stolen Base Percentage by Team":
        team_sb_eff = df.groupby("team")["stolenBasePercentage"].mean().sort_values(ascending=False).reset_index()
        fig = px.bar(team_sb_eff, x="team", y="stolenBasePercentage",
                     title="Average Stolen Base Percentage by Team",
                     labels={"stolenBasePercentage": "Stolen Base %"})
        fig.update_layout(xaxis={'categoryorder':'total descending'})
        st.plotly_chart(fig)

    elif analysis_option == "Stolen Bases vs Games Played":
        fig = px.scatter(df, x="gamesPlayed", y="stolenBases",
                         hover_name="player", color="team",
                         title="Stolen Bases vs Games Played")
        st.plotly_chart(fig)

    elif analysis_option == "Top 10 Power Hitters":
        top_power_hitters = df[df["atBats"] > 100].sort_values("homeRunRate", ascending=False).head(10)
        fig = px.bar(top_power_hitters, x="player", y="homeRunRate", color="team",
                     title="Top 10 Power Hitters (HR Rate, Min 100 AB)")
        st.plotly_chart(fig)

    elif analysis_option == "Batting Average vs On-Base Percentage":
        fig = px.scatter(df, x="avg", y="obp", 
                         color="team", hover_name="player",
                         title="Batting Average vs On-Base Percentage")
        st.plotly_chart(fig)
# Out:
# Overwriting mlb_analysis_app.py
